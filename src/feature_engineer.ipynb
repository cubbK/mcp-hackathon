# %%
from dotenv import load_dotenv
import sqlite3
import json
import pandas as pd
from typing import List, Dict, Any
import openai
import os
from tqdm import tqdm
load_dotenv()  # laddar .env-filen

client = openai.OpenAI()

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Connect to the commits database
conn = sqlite3.connect('commits.db')

# Check the total number of commits
total_commits = conn.execute("SELECT COUNT(*) FROM commits").fetchone()[0]
print(f"Total commits in database: {total_commits}")

# Check a sample commit to understand the structure
sample_commit = conn.execute("SELECT * FROM commits LIMIT 1").fetchone()
print("\nSample commit structure:")
print(f"Repo: {sample_commit[0]}")
print(f"SHA: {sample_commit[1]}")
print(f"Title: {sample_commit[2]}")
print(f"Diffs preview: {sample_commit[3][:200]}...")

# Parse the diffs JSON to see structure
sample_diffs = json.loads(sample_commit[3])
print(f"\nNumber of files changed in sample commit: {len(sample_diffs)}")
if sample_diffs:
    print(f"First diff keys: {list(sample_diffs[0].keys())}")
    if 'diff' in sample_diffs[0] and sample_diffs[0]['diff']:
        print(f"Sample diff content: {sample_diffs[0]['diff'][:300]}...")
# Out:
# Total commits in database: 30
#
# Sample commit structure:
# Repo: https://github.com/hm-group/gcp-projectfactory
# SHA: 88ffb0214cde5bbd88697444e89bf3fe84ec3bad
# Title: Merge pull request #15955 from hm-group/add-workload-identity-to-trendie
# Diffs preview: [{"filename": "projects/trendie-d.yaml", "diff": "@@ -65,3 +65,6 @@ project:\n     - herman.lindstrom@hm.com\n     - andreas.bergstrom@hm.com\n     - manjunath.satishnaik@hm.com\n+  workloadIdentity:\...
#
# Number of files changed in sample commit: 1
# First diff keys: ['filename', 'diff']
# Sample diff content: @@ -65,3 +65,6 @@ project:
#      - herman.lindstrom@hm.com
#      - andreas.bergstrom@hm.com
#      - manjunath.satishnaik@hm.com
# +  workloadIdentity:
# +    - repo: trendie-d-a07f-vertex-pipelines
# +...

# %%
def analyze_diff_with_prompt(filename: str, diff_content: str, commit_title: str, repo: str) -> Dict[str, Any]:
    """
    Analyze a diff using OpenAI to determine if it's interesting.
    """
    
    if not diff_content or diff_content.strip() == "":
        return {
            "score": 0,
            "confidence": 1.0,
            "reason": "Empty diff",
            "category": "empty"
        }
    
    # Truncate diff if it's too long to avoid token limits
    max_diff_length = 2000
    truncated_diff = diff_content[:max_diff_length]
    if len(diff_content) > max_diff_length:
        truncated_diff += "\n... (truncated)"
    
    prompt = f"""
You are an EXTREMELY strict senior software engineer. Rate this code diff on a scale of 0-100 where you are VERY AGGRESSIVE and STINGY with high scores.

Repository: {repo}
Commit Title: {commit_title}
Filename: {filename}

Diff:
```
{truncated_diff}
```

SCORING GUIDELINES (BE RUTHLESS):
- 90-100: Only for EXCEPTIONAL changes like major security fixes, critical performance breakthroughs, or groundbreaking architectural improvements
- 80-89: Significant security vulnerabilities fixed, major performance optimizations, important API changes
- 70-79: Notable bug fixes, meaningful feature additions, important refactoring
- 60-69: Minor bug fixes, small features, routine improvements
- 40-59: Configuration changes, dependency updates, minor refactoring
- 20-39: Test additions, documentation improvements, code style changes
- 0-19: Trivial changes, formatting, comments, variable renames

BE EXTREMELY STRICT. Most commits should score 20-40. Only truly exceptional changes deserve 80+.

Respond with JSON containing:
- "score": integer 0-100 (BE VERY STINGY WITH HIGH SCORES)
- "confidence": float 0.0-1.0 (how confident you are)
- "category": string (one of: "security", "bugfix", "performance", "database", "configuration", "feature", "refactor", "test", "documentation", "infrastructure", "empty", "general")
- "reason": string (brief explanation of the score)

Respond only with valid JSON.
"""

    try:
        response = client.chat.completions.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": "You are an EXTREMELY strict senior software engineer who is very stingy with high scores. Most changes are routine and should score 20-40. Only exceptional changes deserve 70+."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.2,
            max_tokens=200
        )
        
        response_text = response.choices[0].message.content.strip()
        
        # Try to parse the JSON response
        try:
            result = json.loads(response_text)
            
            # Validate required fields
            required_fields = ["score", "confidence", "category", "reason"]
            if not all(field in result for field in required_fields):
                raise ValueError("Missing required fields in response")
            
            # Ensure score is between 0 and 100
            result["score"] = max(0, min(100, int(result["score"])))
            
            # Ensure confidence is between 0 and 1
            result["confidence"] = max(0.0, min(1.0, float(result["confidence"])))
            
            # Add metadata
            result["file_type"] = filename.split('.')[-1] if '.' in filename else "unknown"
            result["lines_added"] = truncated_diff.count('\n+')
            result["lines_removed"] = truncated_diff.count('\n-')
            result["total_changes"] = result["lines_added"] + result["lines_removed"]
            
            return result
            
        except (json.JSONDecodeError, ValueError) as e:
            print(f"Error parsing LLM response for {filename}: {e}")
            print(f"Response was: {response_text}")
            
            # Fallback to basic analysis
            return {
                "score": min(30, len(truncated_diff) // 50),  # Very conservative fallback scoring
                "confidence": 0.3,
                "reason": f"LLM parsing failed: {str(e)}",
                "category": "general",
                "file_type": filename.split('.')[-1] if '.' in filename else "unknown",
                "lines_added": truncated_diff.count('\n+'),
                "lines_removed": truncated_diff.count('\n-'),
                "total_changes": truncated_diff.count('\n+') + truncated_diff.count('\n-')
            }
            
    except Exception as e:
        print(f"Error calling OpenAI API for {filename}: {e}")
        
        # Fallback analysis
        return {
            "score": 0,
            "confidence": 0.1,
            "reason": f"API call failed: {str(e)}",
            "category": "general",
            "file_type": filename.split('.')[-1] if '.' in filename else "unknown",
            "lines_added": 0,
            "lines_removed": 0,
            "total_changes": 0
        }

print("LLM-powered diff analysis function defined!")
# Out:
# LLM-powered diff analysis function defined!

# %%
def process_all_commits(limit=None):
    """
    Process all commits and analyze each diff.
    """
    query = "SELECT repo, sha, title, diffs FROM commits"
    if limit:
        query += f" LIMIT {limit}"
    
    cursor = conn.execute(query)
    results = []
    
    for row in tqdm(cursor.fetchall(), desc="Processing commits"):
        repo, sha, title, diffs_json = row
        
        try:
            diffs = json.loads(diffs_json)
        except json.JSONDecodeError:
            print(f"Error parsing JSON for commit {sha}")
            continue
        
        # Analyze each file diff in the commit
        for diff_data in diffs:
            filename = diff_data.get('filename', 'unknown')
            diff_content = diff_data.get('diff', '')
            
            analysis = analyze_diff_with_prompt(filename, diff_content, title, repo)
            
            result = {
                'repo': repo,
                'sha': sha,
                'commit_title': title,
                'filename': filename,
                'diff_length': len(diff_content) if diff_content else 0,
                **analysis  # Unpack all analysis results
            }
            
            results.append(result)
    
    return pd.DataFrame(results)

# Process a small sample first to test
print("Processing first 3 commits as a test...")
sample_df = process_all_commits(limit=30)
print(f"Processed {len(sample_df)} file diffs from 3 commits")
print(f"Score distribution:")
print(f"  High scores (70+): {(sample_df['score'] >= 70).sum()}")
print(f"  Medium scores (40-69): {((sample_df['score'] >= 40) & (sample_df['score'] < 70)).sum()}")
print(f"  Low scores (0-39): {(sample_df['score'] < 40).sum()}")
print(f"Average score: {sample_df['score'].mean():.1f}")
sample_df.head()
# Out:
# Processing first 3 commits as a test...
# Processing commits: 100%|██████████| 30/30 [02:43<00:00,  5.44s/it]
# Processed 57 file diffs from 3 commits
# Score distribution:
#   High scores (70+): 0
#   Medium scores (40-69): 2
#   Low scores (0-39): 55
# Average score: 33.7
#                                              repo  \
# 0  https://github.com/hm-group/gcp-projectfactory
# 1  https://github.com/hm-group/gcp-projectfactory
# 2  https://github.com/hm-group/gcp-projectfactory
# 3  https://github.com/hm-group/gcp-projectfactory
# 4  https://github.com/hm-group/gcp-projectfactory
#
#                                         sha  \
# 0  88ffb0214cde5bbd88697444e89bf3fe84ec3bad
# 1  b1cc2b81cd112bf50632dc3a71ef61082a1149d6
# 2  adbe6673d057942e4f3e135140d4a8e074c10cfb
# 3  45b80e834853d14114d05a4439206eded65c8b97
# 4  1ecc9c06e01d400d30015d23a83bd6fb936e98f8
#
#                                         commit_title  \
# 0  Merge pull request #15955 from hm-group/add-wo...
# 1  Merge pull request #16004 from hm-group/projec...
# 2                             Adds requested project
# 3  Merge pull request #16003 from hm-group/projec...
# 4                             Adds requested project
#
#                              filename  diff_length  score  confidence  \
# 0             projects/trendie-d.yaml          192     35         0.9
# 1     projects/ml-sa-exploration.yaml          384     35         0.9
# 2     projects/ml-sa-exploration.yaml          384     35         0.9
# 3  projects/sandbox-abhay-0825-1.yaml          373     35         0.9
# 4  projects/sandbox-abhay-0825-1.yaml          373     35         0.9
#
#         category                                             reason file_type  \
# 0  configuration  The change is a simple configuration update, a...      yaml
# 1  configuration  This commit is a simple configuration addition...      yaml
# 2  configuration  This commit simply adds a new project configur...      yaml
# 3  configuration  This is a simple configuration change for a pr...      yaml
# 4  configuration  This commit simply adds a new project configur...      yaml
#
#    lines_added  lines_removed  total_changes
# 0            3              0              3
# 1           17              0             17
# 2           17              0             17
# 3           16              0             16
# 4           16              0             16

# %%
sample_df
# Out:
#                                               repo  \
# 0   https://github.com/hm-group/gcp-projectfactory
# 1   https://github.com/hm-group/gcp-projectfactory
# 2   https://github.com/hm-group/gcp-projectfactory
# 3   https://github.com/hm-group/gcp-projectfactory
# 4   https://github.com/hm-group/gcp-projectfactory
# 5   https://github.com/hm-group/gcp-projectfactory
# 6   https://github.com/hm-group/gcp-projectfactory
# 7   https://github.com/hm-group/gcp-projectfactory
# 8   https://github.com/hm-group/gcp-projectfactory
# 9   https://github.com/hm-group/gcp-projectfactory
# 10  https://github.com/hm-group/gcp-projectfactory
# 11  https://github.com/hm-group/gcp-projectfactory
# 12  https://github.com/hm-group/gcp-projectfactory
# 13  https://github.com/hm-group/gcp-projectfactory
# 14  https://github.com/hm-group/gcp-projectfactory
# 15  https://github.com/hm-group/gcp-projectfactory
# 16  https://github.com/hm-group/gcp-projectfactory
# 17  https://github.com/hm-group/gcp-projectfactory
# 18  https://github.com/hm-group/gcp-projectfactory
# 19  https://github.com/hm-group/gcp-projectfactory
# 20  https://github.com/hm-group/gcp-projectfactory
# 21  https://github.com/hm-group/gcp-projectfactory
# 22  https://github.com/hm-group/gcp-projectfactory
# 23  https://github.com/hm-group/gcp-projectfactory
# 24  https://github.com/hm-group/gcp-projectfactory
# 25  https://github.com/hm-group/gcp-projectfactory
# 26  https://github.com/hm-group/gcp-projectfactory
# 27  https://github.com/hm-group/gcp-projectfactory
# 28  https://github.com/hm-group/gcp-projectfactory
# 29  https://github.com/hm-group/gcp-projectfactory
# 30  https://github.com/hm-group/gcp-projectfactory
# 31  https://github.com/hm-group/gcp-projectfactory
# 32  https://github.com/hm-group/gcp-projectfactory
# 33  https://github.com/hm-group/gcp-projectfactory
# 34  https://github.com/hm-group/gcp-projectfactory
# 35  https://github.com/hm-group/gcp-projectfactory
# 36  https://github.com/hm-group/gcp-projectfactory
# 37  https://github.com/hm-group/gcp-projectfactory
# 38  https://github.com/hm-group/gcp-projectfactory
# 39  https://github.com/hm-group/gcp-projectfactory
# 40  https://github.com/hm-group/gcp-projectfactory
# 41  https://github.com/hm-group/gcp-projectfactory
# 42  https://github.com/hm-group/gcp-projectfactory
# 43  https://github.com/hm-group/gcp-projectfactory
# 44  https://github.com/hm-group/gcp-projectfactory
# 45  https://github.com/hm-group/gcp-projectfactory
# 46  https://github.com/hm-group/gcp-projectfactory
# 47  https://github.com/hm-group/gcp-projectfactory
# 48  https://github.com/hm-group/gcp-projectfactory
# 49  https://github.com/hm-group/gcp-projectfactory
# 50  https://github.com/hm-group/gcp-projectfactory
# 51  https://github.com/hm-group/gcp-projectfactory
# 52  https://github.com/hm-group/gcp-projectfactory
# 53  https://github.com/hm-group/gcp-projectfactory
# 54  https://github.com/hm-group/gcp-projectfactory
# 55  https://github.com/hm-group/gcp-projectfactory
# 56  https://github.com/hm-group/gcp-projectfactory
#
#                                          sha  \
# 0   88ffb0214cde5bbd88697444e89bf3fe84ec3bad
# 1   b1cc2b81cd112bf50632dc3a71ef61082a1149d6
# 2   adbe6673d057942e4f3e135140d4a8e074c10cfb
# 3   45b80e834853d14114d05a4439206eded65c8b97
# 4   1ecc9c06e01d400d30015d23a83bd6fb936e98f8
# 5   02efe890ebd81c1c604f26f3e8cbdeda9b3634f7
# 6   839c9c7cbbaef6eb870adc0055d944075e93b1bc
# 7   eb1e70c1e3e5afa9f91678808b6b9b6d7247f2a9
# 8   a3eab1901ec2e93ec2546c7711f92fab243c9a8a
# 9   b8c20b006f44f7ffa3f8878d3925176575dd5d3f
# 10  4a2e7f986c75aa0a82342e6983dc9e328af51dce
# 11  0d5d0d0183a1613a065f17773e1e394cd170399c
# 12  3394777cf14e148969468832866c2d5437ce0196
# 13  468d5329170ae9dcd2ff392daa74554c848bbf36
# 14  42eeb06eac9ef786ab747c13101c051e55e3910b
# 15  c78481d6c814e7d3c566572ba3b40d638cdfb979
# 16  bfcd5fc0992a75381909d045bf470f5f80ce7863
# 17  5259ca972458f71ca8e7a8b0e8a697d1e6d900d6
# 18  b5fbac7d9edebf161590dc8a985563ca653b4f42
# 19  a3c5018421b444095e458aa209d7eee9effe99f3
# 20  4af07eba31013436b61041413ff7e3b3576c3dcb
# 21  d07839ca9e80890815696bf421ae9bd003d3f837
# 22  2c8758b509b32ef703753d2750979c5403ce85ef
# 23  2c8758b509b32ef703753d2750979c5403ce85ef
# 24  2c8758b509b32ef703753d2750979c5403ce85ef
# 25  2c8758b509b32ef703753d2750979c5403ce85ef
# 26  2c8758b509b32ef703753d2750979c5403ce85ef
# 27  7c485a761085f85da531ad2eafaa5b682d45fe73
# 28  7c485a761085f85da531ad2eafaa5b682d45fe73
# 29  7c485a761085f85da531ad2eafaa5b682d45fe73
# 30  7c485a761085f85da531ad2eafaa5b682d45fe73
# 31  7c485a761085f85da531ad2eafaa5b682d45fe73
# 32  3ef5950adee94ffcdcc48f9c1d616a2ecf611b13
# 33  3ef5950adee94ffcdcc48f9c1d616a2ecf611b13
# 34  3ef5950adee94ffcdcc48f9c1d616a2ecf611b13
# 35  3ef5950adee94ffcdcc48f9c1d616a2ecf611b13
# 36  3ef5950adee94ffcdcc48f9c1d616a2ecf611b13
# 37  fb691ac9f78a0797619b3080f72353f3921557f4
# 38  f1a7030539682a55f694d7220936bbcd6e41aea5
# 39  f1a7030539682a55f694d7220936bbcd6e41aea5
# 40  f1a7030539682a55f694d7220936bbcd6e41aea5
# 41  f1a7030539682a55f694d7220936bbcd6e41aea5
# 42  f1a7030539682a55f694d7220936bbcd6e41aea5
# 43  f514e6480138e02d20684fb37f8d2cdf724aab30
# 44  f514e6480138e02d20684fb37f8d2cdf724aab30
# 45  f514e6480138e02d20684fb37f8d2cdf724aab30
# 46  f514e6480138e02d20684fb37f8d2cdf724aab30
# 47  f514e6480138e02d20684fb37f8d2cdf724aab30
# 48  eecdf717a110c1a7662696c61a14790df34fb656
# 49  eecdf717a110c1a7662696c61a14790df34fb656
# 50  eecdf717a110c1a7662696c61a14790df34fb656
# 51  eecdf717a110c1a7662696c61a14790df34fb656
# 52  eecdf717a110c1a7662696c61a14790df34fb656
# 53  117311e7795d49ee448e0b43caa974c7a9e1a163
# 54  117311e7795d49ee448e0b43caa974c7a9e1a163
# 55  117311e7795d49ee448e0b43caa974c7a9e1a163
# 56  117311e7795d49ee448e0b43caa974c7a9e1a163
#
#                                          commit_title  \
# 0   Merge pull request #15955 from hm-group/add-wo...
# 1   Merge pull request #16004 from hm-group/projec...
# 2                              Adds requested project
# 3   Merge pull request #16003 from hm-group/projec...
# 4                              Adds requested project
# 5   Merge pull request #16002 from hm-group/projec...
# 6                              Adds requested project
# 7   Merge pull request #16001 from hm-group/projec...
# 8                                Updates project file
# 9   Merge pull request #16000 from hm-group/projec...
# 10                               Updates project file
# 11  Merge pull request #15999 from hm-group/projec...
# 12                             Adds requested project
# 13  Merge pull request #15998 from hm-group/jason-...
# 14                    Enable PAM for cp-eng-prod.yaml
# 15  Merge pull request #15997 from hm-group/projec...
# 16                             Adds requested project
# 17  Merge pull request #15995 from hm-group/projec...
# 18  Merge pull request #15994 from hm-group/projec...
# 19  Merge pull request #15991 from hm-group/projec...
# 20  Merge pull request #15990 from hm-group/sanket...
# 21  Merge pull request #15988 from hm-group/projec...
# 22  Merge branch 'master' into projects/jason-pam-...
# 23  Merge branch 'master' into projects/jason-pam-...
# 24  Merge branch 'master' into projects/jason-pam-...
# 25  Merge branch 'master' into projects/jason-pam-...
# 26  Merge branch 'master' into projects/jason-pam-...
# 27  Merge branch 'master' into projects/jason-pam-...
# 28  Merge branch 'master' into projects/jason-pam-...
# 29  Merge branch 'master' into projects/jason-pam-...
# 30  Merge branch 'master' into projects/jason-pam-...
# 31  Merge branch 'master' into projects/jason-pam-...
# 32  Merge branch 'master' into projects/daily-2025...
# 33  Merge branch 'master' into projects/daily-2025...
# 34  Merge branch 'master' into projects/daily-2025...
# 35  Merge branch 'master' into projects/daily-2025...
# 36  Merge branch 'master' into projects/daily-2025...
# 37  Merge pull request #15989 from hm-group/projec...
# 38  Merge branch 'master' into sanket-mhadgut_hmgr...
# 39  Merge branch 'master' into sanket-mhadgut_hmgr...
# 40  Merge branch 'master' into sanket-mhadgut_hmgr...
# 41  Merge branch 'master' into sanket-mhadgut_hmgr...
# 42  Merge branch 'master' into sanket-mhadgut_hmgr...
# 43  Merge branch 'master' into projects/daily-2025...
# 44  Merge branch 'master' into projects/daily-2025...
# 45  Merge branch 'master' into projects/daily-2025...
# 46  Merge branch 'master' into projects/daily-2025...
# 47  Merge branch 'master' into projects/daily-2025...
# 48  Merge branch 'master' into projects/mkt-rba-tr...
# 49  Merge branch 'master' into projects/mkt-rba-tr...
# 50  Merge branch 'master' into projects/mkt-rba-tr...
# 51  Merge branch 'master' into projects/mkt-rba-tr...
# 52  Merge branch 'master' into projects/mkt-rba-tr...
# 53  Merge pull request #15993 from hm-group/fix-do...
# 54  Merge pull request #15993 from hm-group/fix-do...
# 55  Merge pull request #15993 from hm-group/fix-do...
# 56  Merge pull request #15993 from hm-group/fix-do...
#
#                                             filename  diff_length  score  \
# 0                            projects/trendie-d.yaml          192     35
# 1                    projects/ml-sa-exploration.yaml          384     35
# 2                    projects/ml-sa-exploration.yaml          384     35
# 3                 projects/sandbox-abhay-0825-1.yaml          373     35
# 4                 projects/sandbox-abhay-0825-1.yaml          373     35
# 5                     projects/salesstore-sdl-d.yaml         2171     35
# 6                     projects/salesstore-sdl-d.yaml         2171     35
# 7                      projects/audience-mgmt-p.yaml          253     35
# 8                      projects/audience-mgmt-p.yaml          253     35
# 9                          projects/cp-eng-prod.yaml          344     35
# 10                         projects/cp-eng-prod.yaml          344     35
# 11              projects/experience-service-api.yaml          389     35
# 12              projects/experience-service-api.yaml          389     35
# 13                         projects/cp-eng-prod.yaml          217     35
# 14                         projects/cp-eng-prod.yaml          217     40
# 15                         projects/cp-eng-prod.yaml          373     35
# 16                         projects/cp-eng-prod.yaml          373     35
# 17                     projects/jason-pam-test1.yaml          143     35
# 18                projects/jason-pam-prod-test1.yaml          153     30
# 19                    projects/daily-2025-08-10.yaml          145     35
# 20                 projects/salesconsolidated-t.yaml          218     35
# 21                   projects/mkt-rba-traffic-p.yaml          240     20
# 22                 .github/workflows/manual-run.yaml          243     35
# 23               .github/workflows/master-apply.yaml          243     30
# 24    .github/workflows/pull-request-validation.yaml          243     35
# 25  .github/workflows/schedule-cleanup-projects.yaml          243     30
# 26                    projects/daily-2025-08-13.yaml          388     35
# 27                 .github/workflows/manual-run.yaml          243     35
# 28               .github/workflows/master-apply.yaml          243     35
# 29    .github/workflows/pull-request-validation.yaml          243     35
# 30  .github/workflows/schedule-cleanup-projects.yaml          243     35
# 31                    projects/daily-2025-08-13.yaml          388     35
# 32                 .github/workflows/manual-run.yaml          243     35
# 33               .github/workflows/master-apply.yaml          243     30
# 34    .github/workflows/pull-request-validation.yaml          243     35
# 35  .github/workflows/schedule-cleanup-projects.yaml          243     35
# 36                    projects/daily-2025-08-13.yaml          252     35
# 37                    projects/daily-2025-08-13.yaml          388     35
# 38                 .github/workflows/manual-run.yaml          243     35
# 39               .github/workflows/master-apply.yaml          243     35
# 40    .github/workflows/pull-request-validation.yaml          243     35
# 41  .github/workflows/schedule-cleanup-projects.yaml          243     35
# 42                    projects/daily-2025-07-09.yaml          388     25
# 43                 .github/workflows/manual-run.yaml          243     35
# 44               .github/workflows/master-apply.yaml          243     35
# 45    .github/workflows/pull-request-validation.yaml          243     35
# 46  .github/workflows/schedule-cleanup-projects.yaml          243     35
# 47                    projects/daily-2025-07-09.yaml          388     10
# 48                 .github/workflows/manual-run.yaml          243     35
# 49               .github/workflows/master-apply.yaml          243     35
# 50    .github/workflows/pull-request-validation.yaml          243     35
# 51  .github/workflows/schedule-cleanup-projects.yaml          243     35
# 52                    projects/daily-2025-07-09.yaml          388     20
# 53                 .github/workflows/manual-run.yaml          243     40
# 54               .github/workflows/master-apply.yaml          243     35
# 55    .github/workflows/pull-request-validation.yaml          243     35
# 56  .github/workflows/schedule-cleanup-projects.yaml          243     35
#
#     confidence       category  \
# 0         0.90  configuration
# 1         0.90  configuration
# 2         0.90  configuration
# 3         0.90  configuration
# 4         0.90  configuration
# 5         0.90  configuration
# 6         0.90  configuration
# 7         1.00  configuration
# 8         0.90  configuration
# 9         0.90  configuration
# 10        0.90  configuration
# 11        0.90  configuration
# 12        0.90  configuration
# 13        0.90  configuration
# 14        0.90  configuration
# 15        0.90  configuration
# 16        0.90  configuration
# 17        0.90  configuration
# 18        1.00  configuration
# 19        0.90  configuration
# 20        0.95  configuration
# 21        1.00  configuration
# 22        0.90  configuration
# 23        0.90  configuration
# 24        0.90  configuration
# 25        0.90  configuration
# 26        0.90  configuration
# 27        0.90  configuration
# 28        0.90  configuration
# 29        0.90  configuration
# 30        0.90  configuration
# 31        0.90  configuration
# 32        0.90  configuration
# 33        1.00  configuration
# 34        0.90  configuration
# 35        0.90  configuration
# 36        0.90  configuration
# 37        0.90  configuration
# 38        0.95  configuration
# 39        0.90  configuration
# 40        0.90  configuration
# 41        0.90  configuration
# 42        0.90  configuration
# 43        0.90  configuration
# 44        0.95  configuration
# 45        0.90  configuration
# 46        0.90  configuration
# 47        0.90  configuration
# 48        0.90  configuration
# 49        0.90  configuration
# 50        0.90  configuration
# 51        0.90  configuration
# 52        0.90  configuration
# 53        0.90  configuration
# 54        0.90  configuration
# 55        0.90  configuration
# 56        0.90  configuration
#
#                                                reason file_type  lines_added  \
# 0   The change is a simple configuration update, a...      yaml            3
# 1   This commit is a simple configuration addition...      yaml           17
# 2   This commit simply adds a new project configur...      yaml           17
# 3   This is a simple configuration change for a pr...      yaml           16
# 4   This commit simply adds a new project configur...      yaml           16
# 5   This commit is a configuration change for a pr...      yaml           67
# 6   This commit is a routine configuration change ...      yaml           67
# 7   This is a simple configuration change, adjusti...      yaml            1
# 8   This change is a simple configuration update, ...      yaml            1
# 9   The changes made in this commit are mostly con...      yaml            5
# 10  The changes are minor configuration adjustment...      yaml            5
# 11  This commit is a basic configuration change fo...      yaml           16
# 12  This commit simply adds a new project configur...      yaml           16
# 13  The change is a simple configuration update, a...      yaml            2
# 14  This change is a simple configuration update, ...      yaml            2
# 15  This commit is a simple configuration addition...      yaml           16
# 16  This commit only adds a new project configurat...      yaml           16
# 17  This change is a simple configuration update, ...      yaml            1
# 18  This change is a simple configuration update, ...      yaml            1
# 19  The change is a simple configuration update, c...      yaml            1
# 20  This change is a simple configuration update, ...      yaml            1
# 21  This change is merely a removal of an email fr...      yaml            0
# 22  This change is a simple downgrade of a GitHub ...      yaml            1
# 23  This change is a simple downgrade of a version...      yaml            1
# 24  The change is a minor version downgrade in a w...      yaml            1
# 25  The change is a minor version downgrade of a G...      yaml            1
# 26  This commit only includes a configuration file...      yaml           16
# 27  The change is a minor version downgrade in a G...      yaml            1
# 28  This change is a minor version downgrade of a ...      yaml            1
# 29  The change is a minor version downgrade in a G...      yaml            1
# 30  This change is a minor version downgrade in a ...      yaml            1
# 31  This commit is a simple configuration change f...      yaml           16
# 32  The change is a minor version downgrade in a G...      yaml            1
# 33  The change is a minor version downgrade of a G...      yaml            1
# 34  The change is a minor version downgrade in a G...      yaml            1
# 35  The change is a minor version downgrade in a G...      yaml            1
# 36  This change is a simple configuration update, ...      yaml            3
# 37  This commit is a simple configuration change f...      yaml           16
# 38  The change is a minor version downgrade in a G...      yaml            1
# 39  The change is a minor version downgrade in a G...      yaml            1
# 40  This change is a minor version downgrade in a ...      yaml            1
# 41  The change is a minor version downgrade in a G...      yaml            1
# 42  This commit only involves the deletion of a pr...      yaml            0
# 43  The change is a minor version downgrade in a w...      yaml            1
# 44  The change is a minor version downgrade in a G...      yaml            1
# 45  The change is a minor version downgrade in a G...      yaml            1
# 46  This change is a simple downgrade of a depende...      yaml            1
# 47  The commit is a simple deletion of a project c...      yaml            0
# 48  The change is a minor version downgrade of a G...      yaml            1
# 49  The change is a minor version downgrade in a G...      yaml            1
# 50  The change is a minor version downgrade of a G...      yaml            1
# 51  The change is a minor version downgrade in a G...      yaml            1
# 52  This commit involves the deletion of a project...      yaml            0
# 53  The change is a minor version downgrade in a G...      yaml            1
# 54  This change is a simple version downgrade of a...      yaml            1
# 55  The change is a minor version downgrade in a G...      yaml            1
# 56  The change is a minor version downgrade in a w...      yaml            1
#
#     lines_removed  total_changes
# 0               0              3
# 1               0             17
# 2               0             17
# 3               0             16
# 4               0             16
# 5               0             67
# 6               0             67
# 7               1              2
# 8               1              2
# 9               2              7
# 10              2              7
# 11              0             16
# 12              0             16
# 13              0              2
# 14              0              2
# 15              0             16
# 16              0             16
# 17              1              2
# 18              1              2
# 19              1              2
# 20              1              2
# 21              1              1
# 22              1              2
# 23              1              2
# 24              1              2
# 25              1              2
# 26              0             16
# 27              1              2
# 28              1              2
# 29              1              2
# 30              1              2
# 31              0             16
# 32              1              2
# 33              1              2
# 34              1              2
# 35              1              2
# 36              3              6
# 37              0             16
# 38              1              2
# 39              1              2
# 40              1              2
# 41              1              2
# 42             16             16
# 43              1              2
# 44              1              2
# 45              1              2
# 46              1              2
# 47             16             16
# 48              1              2
# 49              1              2
# 50              1              2
# 51              1              2
# 52             16             16
# 53              1              2
# 54              1              2
# 55              1              2
# 56              1              2

# %%
# First, let's check the current structure of the commits table
cursor = conn.cursor()
table_info = cursor.execute("PRAGMA table_info(commits)").fetchall()
print("Current commits table structure:")
for column in table_info:
    print(f"  {column[1]} ({column[2]})")

# Add new columns to the existing commits table for the analysis results
def add_analysis_columns():
    """
    Add analysis columns to the existing commits table.
    """
    cursor = conn.cursor()
    
    # List of new columns to add
    new_columns = [
        "ADD COLUMN filename TEXT",
        "ADD COLUMN diff_length INTEGER",
        "ADD COLUMN score INTEGER",
        "ADD COLUMN confidence REAL",
        "ADD COLUMN reason TEXT", 
        "ADD COLUMN category TEXT",
        "ADD COLUMN file_type TEXT",
        "ADD COLUMN lines_added INTEGER",
        "ADD COLUMN lines_removed INTEGER",
        "ADD COLUMN total_changes INTEGER"
    ]
    
    # Add each column (SQLite will ignore if column already exists)
    for column in new_columns:
        try:
            cursor.execute(f"ALTER TABLE commits {column}")
            print(f"Added column: {column.split()[-2]}")
        except sqlite3.OperationalError as e:
            if "duplicate column name" in str(e):
                print(f"Column {column.split()[-2]} already exists")
            else:
                print(f"Error adding column {column.split()[-2]}: {e}")
    
    conn.commit()
    print("Finished adding analysis columns to commits table!")

# Function to update the commits table with analysis data
def update_commits_with_analysis(df):
    """
    Update the commits table with analysis data from the dataframe.
    Since we need to handle multiple files per commit, we'll need to create
    separate rows for each file or aggregate the data.
    """
    cursor = conn.cursor()
    
    # Group by commit (sha) and aggregate the analysis data
    commit_aggregates = df.groupby('sha').agg({
        'score': 'mean',  # Average score across all files
        'confidence': 'mean',  # Average confidence
        'category': lambda x: ', '.join(x.unique()),  # Concatenate unique categories
        'file_type': lambda x: ', '.join(x.unique()),  # Concatenate unique file types
        'lines_added': 'sum',  # Total lines added
        'lines_removed': 'sum',  # Total lines removed
        'total_changes': 'sum',  # Total changes
        'diff_length': 'sum',  # Total diff length
        'reason': lambda x: x.iloc[0]  # Take first reason as representative
    }).round(2)
    
    # Update each commit with aggregated analysis data
    for sha, data in commit_aggregates.iterrows():
        cursor.execute('''
            UPDATE commits 
            SET score = ?, confidence = ?, reason = ?, category = ?, 
                file_type = ?, lines_added = ?, lines_removed = ?, 
                total_changes = ?, diff_length = ?
            WHERE sha = ?
        ''', (
            data['score'],
            data['confidence'], 
            data['reason'],
            data['category'],
            data['file_type'],
            data['lines_added'],
            data['lines_removed'],
            data['total_changes'],
            data['diff_length'],
            sha
        ))
    
    conn.commit()
    print(f"Updated {len(commit_aggregates)} commits with analysis data!")

# Execute the functions
add_analysis_columns()
update_commits_with_analysis(sample_df)

# Verify the updates
verification_query = conn.execute("""
    SELECT repo, sha, title, score, category, lines_added, lines_removed 
    FROM commits 
    WHERE score IS NOT NULL 
    LIMIT 5
""").fetchall()

print(f"\nSample of updated commits:")
for row in verification_query:
    print(f"Repo: {row[0]}, SHA: {row[1][:8]}..., Score: {row[3]}, Category: {row[4]}")
# Out:
# Current commits table structure:
#   repo (TEXT)
#   sha (TEXT)
#   title (TEXT)
#   diffs (TEXT)
#   filename (TEXT)
#   diff_length (INTEGER)
#   score (INTEGER)
#   confidence (REAL)
#   reason (TEXT)
#   category (TEXT)
#   file_type (TEXT)
#   lines_added (INTEGER)
#   lines_removed (INTEGER)
#   total_changes (INTEGER)
# Column filename already exists
# Column diff_length already exists
# Column score already exists
# Column confidence already exists
# Column reason already exists
# Column category already exists
# Column file_type already exists
# Column lines_added already exists
# Column lines_removed already exists
# Column total_changes already exists
# Finished adding analysis columns to commits table!
# Updated 30 commits with analysis data!
#
# Sample of updated commits:
# Repo: https://github.com/hm-group/gcp-projectfactory, SHA: 88ffb021..., Score: 35, Category: configuration
# Repo: https://github.com/hm-group/gcp-projectfactory, SHA: b1cc2b81..., Score: 35, Category: configuration
# Repo: https://github.com/hm-group/gcp-projectfactory, SHA: adbe6673..., Score: 35, Category: configuration
# Repo: https://github.com/hm-group/gcp-projectfactory, SHA: 45b80e83..., Score: 35, Category: configuration
# Repo: https://github.com/hm-group/gcp-projectfactory, SHA: 1ecc9c06..., Score: 35, Category: configuration
